# %% [markdown]
# # Fst for 1000 genomes

# %%
import re, os, sys, pickle, pickle
from pathlib import Path
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
from sklearn.decomposition import PCA

# my own libaries
from GenomicWindows import window
import GenomicIntervals

np.random.seed(7)

# %% [markdown]
# Plotting setup:

# %%
# %matplotlib inline

# Make inline plots vector graphics instead of raster graphics
from IPython.display import set_matplotlib_formats
#set_matplotlib_formats('pdf', 'svg')
set_matplotlib_formats('retina', 'png')

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from matplotlib.patches import Rectangle
from mpl_toolkits.basemap import Basemap
#matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

import mpld3

import seaborn as sns
sns.set()
sns.set_style("whitegrid")
sns.set_context("paper")

# lowess for plotting
from statsmodels.nonparametric.smoothers_lowess import lowess

def stairs(df, start='start', end='end', pos='pos', endtrim=0):
    "Turn a df with start, end into one with pos to plot as stairs"
    df1 = df.copy(deep=True)
    df2 = df.copy(deep=True)
    df1[pos] = df1[start]
    df2[pos] = df2[end] - endtrim
    return pandas.concat([df1, df2]).sort_values([start, end])

# %% [markdown]
# Ignore deprecation warnings from mainly seaborn:

# %%
# silence deprecation warnings (lots from seaborn)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=np.VisibleDeprecationWarning)
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %% [markdown]
# Import variables global to the entire analysis:

# %%
import analysis_globals as ag

# %% [markdown]
# Local code in the scripts dir on the cluster:

# %%
scripts_dir = ag.root_dir / 'scripts'
if str(scripts_dir) not in sys.path:
    sys.path.append(str(scripts_dir))

import simons_meta_data
import hg19_chrom_sizes

# %% [markdown]
# ## Convenience functions

# %%
def silent_nanmean(x):
    with warnings.catch_warnings():
        warnings.simplefilter("ignore")
        return numpy.nanmean(x)
    
def ident_scalar(s):
    x = s.unique()
    assert(len(x)) == 1
    return x[0]

def flatten_column_index(df):
    df.columns = ['_'.join(col).strip() for col in df.columns.values]

# %% [markdown]
# ## Load meta data

# %%
# easy loading of meta data in a consistent manner across code
meta_data_dir = Path(os.environ['HOME'], 'simons/faststorage/data/metadata')
individuals, populations, regions = simons_meta_data.get_meta_data(meta_data_dir=meta_data_dir)

pop_categories = pd.read_hdf(str(ag.results_dir / 'population_categories.store'), 'sr')
region_categories = pd.read_hdf(str(ag.results_dir / 'region_categories.store'), 'sr')
# region_colors = dict(zip(list(region_categories), 
#                          ['#e41a1c', '#377eb8', '#4daf4a', '#984ea3', 
#                           '#ff7f00', '#ffff33', '#a65628']))

region_colors = dict(zip(list(region_categories), 
                         ['#e41a1c', '#377eb8',  '#984ea3', '#4daf4a',
                          '#ff7f00', '#ffff33', '#a65628']))

chromosome_lengths = dict((k.replace('chr', ''), v) for k, v in hg19_chrom_sizes.hg19_chrom_sizes.items())

# %%
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
#df.iloc[0, 2] = np.nan
df.style.background_gradient(cmap=sns.diverging_palette(250, 10, as_cmap=True))
# Out:
# <style  type="text/css" >
#     #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col0 {
#             background-color:  #4479bb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col1 {
#             background-color:  #e1616b;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col2 {
#             background-color:  #9cb8db;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col3 {
#             background-color:  #739acc;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col4 {
#             background-color:  #a4bede;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col0 {
#             background-color:  #6a94c9;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col1 {
#             background-color:  #7ea2d0;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col2 {
#             background-color:  #4479bb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col3 {
#             background-color:  #f7d7d9;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col4 {
#             background-color:  #f6cdd0;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col0 {
#             background-color:  #91b0d7;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col1 {
#             background-color:  #4479bb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col2 {
#             background-color:  #f4c3c7;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col3 {
#             background-color:  #f4c3c7;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col4 {
#             background-color:  #da3b46;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col0 {
#             background-color:  #b9cde6;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col1 {
#             background-color:  #e98b92;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col2 {
#             background-color:  #f7d3d6;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col3 {
#             background-color:  #5686c1;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col4 {
#             background-color:  #ec999f;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row4_col0 {
#             background-color:  #e0e9f4;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row4_col1 {
#             background-color:  #df545e;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row4_col2 {
#             background-color:  #de4e59;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row4_col3 {
#             background-color:  #c7d7eb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row4_col4 {
#             background-color:  #f2b9bd;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row5_col0 {
#             background-color:  #f9dddf;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row5_col1 {
#             background-color:  #628fc6;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row5_col2 {
#             background-color:  #eb949a;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row5_col3 {
#             background-color:  #db404c;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row5_col4 {
#             background-color:  #f2f2f2;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row6_col0 {
#             background-color:  #f1b5b9;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row6_col1 {
#             background-color:  #fae7e8;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row6_col2 {
#             background-color:  #da3b46;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row6_col3 {
#             background-color:  #aac2e0;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row6_col4 {
#             background-color:  #de515c;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row7_col0 {
#             background-color:  #e98b92;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row7_col1 {
#             background-color:  #f6cdd0;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row7_col2 {
#             background-color:  #de515c;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row7_col3 {
#             background-color:  #6691c7;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row7_col4 {
#             background-color:  #f2b9bd;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row8_col0 {
#             background-color:  #e1626c;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row8_col1 {
#             background-color:  #da3b46;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row8_col2 {
#             background-color:  #5182bf;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row8_col3 {
#             background-color:  #da3b46;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row8_col4 {
#             background-color:  #4479bb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row9_col0 {
#             background-color:  #da3b46;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row9_col1 {
#             background-color:  #e3ebf5;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row9_col2 {
#             background-color:  #e98991;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row9_col3 {
#             background-color:  #4479bb;
#         }    #T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row9_col4 {
#             background-color:  #f6cdd0;
#         }</style>
# <table id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >A</th>
#         <th class="col_heading level0 col1" >B</th>
#         <th class="col_heading level0 col2" >C</th>
#         <th class="col_heading level0 col3" >D</th>
#         <th class="col_heading level0 col4" >E</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col0" class="data row0 col0" >1</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col1" class="data row0 col1" >1.32921</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col2" class="data row0 col2" >-0.770033</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col3" class="data row0 col3" >-0.31628</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row0_col4" class="data row0 col4" >-0.99081</td>
#     </tr>    <tr>
#         <th id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col0" class="data row1 col0" >2</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col1" class="data row1 col1" >-1.07082</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col2" class="data row1 col2" >-1.43871</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col3" class="data row1 col3" >0.564417</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row1_col4" class="data row1 col4" >0.295722</td>
#     </tr>    <tr>
#         <th id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col0" class="data row2 col0" >3</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col1" class="data row2 col1" >-1.6264</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col2" class="data row2 col2" >0.219565</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col3" class="data row2 col3" >0.678805</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row2_col4" class="data row2 col4" >1.88927</td>
#     </tr>    <tr>
#         <th id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col0" class="data row3 col0" >4</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col1" class="data row3 col1" >0.961538</td>
#         <td id="T_995f452a_6759_11e9_afa0_c8cbb8cf78c0row3_col2" class="data row3 col2" >0.104011</td>
#         <td id="T_9

# %%
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "4pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
np.random.seed(25)
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)
bigdf = pd.DataFrame(np.random.randn(100, 120)).cumsum()

bigdf.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '50px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0 th {
#           font-size: 4pt;
#     }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0 td {
#           padding: 0em 0em;
#     }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0 th:hover {
#           font-size: 12pt;
#     }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col0 {
#             background-color:  #ecf2f8;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col1 {
#             background-color:  #b8cce5;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col2 {
#             background-color:  #efb1be;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col3 {
#             background-color:  #f3c2cc;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col4 {
#             background-color:  #eeaab7;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col5 {
#             background-color:  #f8dce2;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col6 {
#             background-color:  #f2c1cb;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col7 {
#             background-color:  #83a6d2;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col8 {
#             background-color:  #de5f79;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col9 {
#             background-color:  #c3d4e9;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col10 {
#             background-color:  #eeacba;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col11 {
#             background-color:  #f7dae0;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col12 {
#             background-color:  #6f98ca;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col13 {
#             background-color:  #e890a1;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col14 {
#             background-color:  #f2f2f2;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col15 {
#             background-color:  #ea96a7;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col16 {
#             background-color:  #adc4e1;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col17 {
#             background-color:  #eca3b1;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col18 {
#             background-color:  #b7cbe5;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col19 {
#             background-color:  #f5ced6;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col20 {
#             background-color:  #6590c7;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col21 {
#             background-color:  #d73c5b;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col22 {
#             background-color:  #4479bb;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col23 {
#             background-color:  #cfddee;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col24 {
#             background-color:  #e58094;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col25 {
#             background-color:  #e0657d;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col26 {
#             background-color:  #d9e4f1;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col27 {
#             background-color:  #f7d6dd;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col28 {
#             background-color:  #f4c8d0;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col29 {
#             background-color:  #799fce;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col30 {
#             background-color:  #ecf2f8;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col31 {
#             background-color:  #e16d85;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col32 {
#             background-color:  #92b1d7;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col33 {
#             background-color:  #e3ebf5;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col34 {
#             background-color:  #e2eaf4;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col35 {
#             background-color:  #e2eaf4;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col36 {
#             background-color:  #f2f2f2;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col37 {
#             background-color:  #f2bfca;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col38 {
#             background-color:  #ebf1f8;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col39 {
#             background-color:  #e0667e;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col40 {
#             background-color:  #f2f2f2;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col41 {
#             background-color:  #e16b82;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col42 {
#             background-color:  #ebf1f8;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col43 {
#             background-color:  #f1bbc6;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col44 {
#             background-color:  #e4ecf5;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col45 {
#             background-color:  #f4c8d0;
#             max-width:  50px;
#             font-size:  1pt;
#         }    #T_9fe52360_6759_11e9_afa0_c8cbb8cf78c0row0_col46 {
